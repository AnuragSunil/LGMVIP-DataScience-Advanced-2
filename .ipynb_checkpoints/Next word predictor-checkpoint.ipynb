# %%
import random 
import pickle
import re

import numpy as np
import pandas as pd
from nltk.tokenize import RegexpTokenizer

from tensorflow.keras.models import Sequential,load_model
from tensorflow.keras.layers import LSTM,Dense,Activation
from tensorflow.keras.optimizers import RMSprop

# %%
with open('1661-0.txt', 'r', encoding='utf-8') as file:
    text = file.read()

clean_text = re.sub(r'[^a-zA-Z\s]', '', text).lower()

# %%
tokenizer = RegexpTokenizer(r'\w+')
tokens = tokenizer.tokenize(clean_text)

# %%
unique_tokens = np.unique(tokens)
unique_token_index = {token: idx for idx,token in enumerate(unique_tokens)}
unique_token_index
# Out:
# {'a': 0,
#  'abandoned': 1,
#  'abhorrent': 2,
#  'absorb': 3,
#  'accomplished': 4,
#  'account': 5,
#  'across': 6,
#  'actions': 7,
#  'active': 8,
#  'activity': 9,
#  'address': 10,
#  'adjusted': 11,
#  'adler': 12,
#  'admirable': 13,
#  'admirably': 14,
#  'admit': 15,
#  'adventure': 16,
#  'adventures': 17,
#  'again': 18,
#  'against': 19,
#  'ago': 20,
#  'akin': 21,
#  'all': 22,
#  'almost': 23,
#  'aloud': 24,
#  'alternating': 25,
#  'always': 26,
#  'am': 27,
#  'ambition': 28,
#  'amiss': 29,
#  'among': 30,
#  'an': 31,
#  'and': 32,
#  'anonymous': 33,
#  'answered': 34,
#  'any': 35,
#  'anyone': 36,
#  'anywhere': 37,
#  'appears': 38,
#  'are': 39,
#  'armchair': 40,
#  'around': 41,
#  'arthur': 42,
#  'as': 43,
#  'asked': 44,
#  'associated': 45,
#  'at': 46,
#  'atkinson': 47,
#  'attention': 48,
#  'attitude': 49,
#  'attracted': 50,
#  'author': 51,
#  'away': 52,
#  'bachelor': 53,
#  'baffled': 54,
#  'baker': 55,
#  'balanced': 56,
#  'band': 57,
#  'be': 58,
#  'because': 59,
#  'beeches': 60,
#  'been': 61,
#  'before': 62,
#  'begins': 63,
#  'behind': 64,
#  'being': 65,
#  'believe': 66,
#  'bell': 67,
#  'beryl': 68,
#  'between': 69,
#  'beyond': 70,
#  'black': 71,
#  'blind': 72,
#  'blue': 73,
#  'bohemia': 74,
#  'bohemian': 75,
#  'books': 76,
#  'bootslitting': 77,
#  'boscombe': 78,
#  'both': 79,
#  'bought': 80,
#  'boy': 81,
#  'brilliantly': 82,
#  'brothers': 83,
#  'brown': 84,
#  'bulge': 85,
#  'buried': 86,
#  'burned': 87,
#  'but': 88,
#  'by': 89,
#  'call': 90,
#  'came': 91,
#  'can': 92,
#  'cant': 93,
#  'capital': 94,
#  'carbuncle': 95,
#  'carefully': 96,
#  'careless': 97,
#  'carelessly': 98,
#  'carlsbad': 99,
#  'case': 100,
#  'caused': 101,
#  'centuries': 102,
#  'certainly': 103,
#  'chamber': 104,
#  'changed': 105,
#  'character': 106,
#  'chest': 107,
#  'chronicle': 108,
#  'chuckled': 109,
#  'cigarette': 110,
#  'cigars': 111,
#  'civil': 112,
#  'clasped': 113,
#  'clear': 114,
#  'clearing': 115,
#  'clothes': 116,
#  'cloud': 117,
#  'clues': 118,
#  'clumsy': 119,
#  'co': 120,
#  'cocaine': 121,
#  'cold': 122,
#  'companion': 123,
#  'companions': 124,
#  'company': 125,
#  'complete': 126,
#  'conan': 127,
#  'construction': 128,
#  'consult': 129,
#  'contents': 130,
#  'continental': 131,
#  'contraction': 132,
#  'copper': 133,
#  'copy': 134,
#  'corner': 135,
#  'coronet': 136,
#  'cost': 137,
#  'could': 138,
#  'country': 139,
#  'countryin': 140,
#  'course': 141,
#  'cover': 142,
#  'crack': 143,
#  'crime': 144,
#  'crown': 145,
#  'crusted': 146,
#  'customary': 147,
#  'cuts': 148,
#  'daily': 149,
#  'dark': 150,
#  'data': 151,
#  'date': 152,
#  'dear': 153,
#  'death': 154,
#  'deduce': 155,
#  'deduction': 156,
#  'deepest': 157,
#  'deeply': 158,
#  'delicate': 159,
#  'delicately': 160,
#  'desire': 161,
#  'desires': 162,
#  'did': 163,
#  'distinction': 164,
#  'distracting': 165,
#  'disturbing': 166,
#  'do': 167,
#  'doings': 168,
#  'dont': 169,
#  'door': 170,
#  'double': 171,
#  'doubt': 172,
#  'down': 173,
#  'doyle': 174,
#  'drawing': 175,
#  'dreadful': 176,
#  'dreams': 177,
#  'drifted': 178,
#  'drowsiness': 179,
#  'drug': 180,
#  'drugcreated': 181,
#  'dubious': 182,
#  'dull': 183,
#  'e': 184,
#  'each': 185,
#  'eagerly': 186,
#  'ease': 187,
#  'easily': 188,
#  'ebook': 189,
#  'eclipses': 190,
#  'edges': 191,
#  'effusive': 192,
#  'eg': 193,
#  'eglonitzhere': 194,
#  'eglow': 195,
#  'egria': 196,
#  'eight': 197,
#  'either': 198,
#  'emotion': 199,
#  'emotions': 200,
#  'employing': 201,
#  'encoding': 202,
#  'endeavouring': 203,
#  'energy': 204,
#  'engineers': 205,
#  'english': 206,
#  'enough': 207,
#  'establishment': 208,
#  'europe': 209,
#  'even': 210,
#  'ever': 211,
#  'every': 212,
#  'exaggerated': 213,
#  'examined': 214,
#  'example': 215,
#  'experiences': 216,
#  'explain': 217,
#  'explained': 218,
#  'extraordinary': 219,
#  'eye': 220,
#  'eyes': 221,
#  'factor': 222,
#  'facts': 223,
#  'faculties': 224,
#  'fail': 225,
#  'false': 226,
#  'family': 227,
#  'fancy': 228,
#  'far': 229,
#  'fashion': 230,
#  'felt': 231,
#  'few': 232,
#  'fierce': 233,
#  'figure': 234,
#  'finally': 235,
#  'finds': 236,
#  'finely': 237,
#  'fire': 238,
#  'firelight': 239,
#  'first': 240,
#  'five': 241,
#  'following': 242,
#  'for': 243,
#  'forefinger': 244,
#  'form': 245,
#  'former': 246,
#  'formerly': 247,
#  'frenchman': 248,
#  'frequently': 249,
#  'friend': 250,
#  'from': 251,
#  'g': 252,
#  'gasogene': 253,
#  'gazetteer': 254,
#  'gentleman': 255,
#  'german': 256,
#  'germanspeaking': 257,
#  'gesellschaft': 258,
#  'getting': 259,
#  'gibe': 260,
#  'girl': 261,
#  'give': 262,
#  'given': 263,
#  'glad': 264,
#  'glance': 265,
#  'glassfactories': 266,
#  'go': 267,
#  'good': 268,
#  'great': 269,
#  'grit': 270,
#  'gutenberg': 271,
#  'gutenbergs': 272,
#  'ha': 273,
#  'habit': 274,
#  'had': 275,
#  'half': 276,
#  'hall': 277,
#  'hands': 278,
#  'happiness': 279,
#  'hardly': 280,
#  'harness': 281,
#  'has': 282,
#  'have': 283,
#  'he': 284,
#  'head': 285,
#  'hear': 286,
#  'heard': 287,
#  'heavy': 288,
#  'help': 289,
#  'hence': 290,
#  'her': 291,
#  'highpower': 292,
#  'him': 293,
#  'himself': 294,
#  'his': 295,
#  'hold': 296,
#  'holland': 297,
#  'holmes': 298,
#  'home': 299,
#  'homecentred': 300,
#  'hopeless': 301,
#  'hot': 302,
#  'hour': 303,
#  'houses': 304,
#  'how': 305,
#  'however': 306,
#  'hundreds': 307,
#  'i': 308,
#  'identity': 309,
#  'if': 310,
#  'ii': 311,
#  'iii': 312,
#  'imagine': 313,
#  'imitate': 314,
#  'immense': 315,
#  'importance': 316,
#  'in': 317,
#  'incidents': 318,
#  'included': 319,
#  'incorrigible': 320,
#  'indeed': 321,
#  'indicated': 322,
#  'insensibly': 323,
#  'inside': 324,
#  'instance': 325,
#  'instead': 326,
#  'instrument': 327,
#  'intended': 328,
#  'interested': 329,
#  'interests': 330,
#  'into': 331,
#  'introduce': 332,
#  'introspective': 333,
#  'intrusions': 334,
#  'iodoform': 335,
#  'irene': 336,
#  'is': 337,
#  'it': 338,
#  'its': 339,
#  'itself': 340,
#  'iv': 341,
#  'ix': 342,
#  'jane': 343,
#  'jose': 344,
#  'journey': 345,
#  'just': 346,
#  'keen': 347,
#  'kindly': 348,
#  'knew': 349,
#  'know': 350,
#  'language': 351,
#  'large': 352,
#  'last': 353,
#  'late': 354,
#  'lately': 355,
#  'laughing': 356,
#  'lead': 357,
#  'league': 358,
#  'leather': 359,
#  'led': 360,
#  'left': 361,
#  'lenses': 362,
#  'let': 363,
#  'license': 364,
#  'light': 365,
#  'lighting': 366,
#  'like': 367,
#  'lip': 368,
#  'lit': 369,
#  'little': 370,
#  'lived': 371,
#  'loathed': 372,
#  'lodgings': 373,
#  'london': 374,
#  'long': 375,
#  'looked': 376,
#  'love': 377,
#  'lover': 378,
#  'lying': 379,
#  'machine': 380,
#  'made': 381,
#  'make': 382,
#  'maker': 383,
#  'malignant': 384,
#  'man': 385,
#  'manner': 386,
#  'many': 387,
#  'march': 388,
#  'mark': 389,
#  'marriage': 390,
#  'mary': 391,
#  'mask': 392,
#  'master': 393,
#  'matter': 394,
#  'matters': 395,
#  'may': 396,
#  'me': 397,
#  'means': 398,
#  'medical': 399,
#  'member': 400,
#  'memory': 401,
#  'menendez': 402,
#  'mens': 403,
#  'mental': 404,
#  'mention': 405,
#  'merely': 406,
#  'mess': 407,
#  'might': 408,
#  'mind': 409,
#  'mission': 410,
#  'mistake': 411,
#  'moment': 412,
#  'monogram': 413,
#  'mood': 414,
#  'more': 415,
#  'most': 416,
#  'motives': 417,
#  'much': 418,
#  'mud': 419,
#  'murder': 420,
#  'must': 421,
#  'my': 422,
#  'myself': 423,
#  'mysteries': 424,
#  'mystery': 425,
#  'name': 426,
#  'nature': 427,
#  'nervous': 428,
#  'never': 429,
#  'new': 430,
#  'nightit': 431,
#  'nitrate': 432,
#  'no': 433,
#  'noble': 434,
#  'not': 435,
#  'note': 436,
#  'notepaper': 437,
#  'notice': 438,
#  'november': 439,
#  'now': 440,
#  'numerous': 441,
#  'observation': 442,
#  'observe': 443,
#  'observed': 444,
#  'observerexcellent': 445,
#  'observing': 446,
#  'obviously': 447,
#  'occupied': 448,
#  'oclock': 449,
#  'odessa': 450,
#  'of': 451,
#  'official': 452,
#  'often': 453,
#  'old': 454,
#  'on': 455,
#  'one': 456,
#  'online': 457,
#  'open': 458,
#  'or': 459,
#  'orange': 460,
#  'order': 461,
#  'other': 462,
#  'our': 463,
#  'out': 464,
#  'over': 465,
#  'own': 466,
#  'p': 467,
#  'pacing': 468,
#  'packet': 469,
#  'paper': 470,
#  'papermills': 471,
#  'papier': 472,
#  'parallel': 473,
#  'part': 474,
#  'particularly': 475,
#  'pass': 476,
#  'passed': 477,
#  'passions': 478,
#  'patient': 479,
#  'peculiar': 480,
#  'peculiarly': 481,
#  'peculiarthat': 482,
#  'perfect': 483,
#  'pinktinted': 484,
#  'pips': 485,
#  'placed': 486,
#  'point': 487,
#  'police': 488,
#  'position': 489,
#  'post': 490,
#  'pounds': 491,
#  'powers': 492,
#  'practice': 493,
#  'precise': 494,
#  'precisely': 495,
#  'predominates': 496,
#  'press': 497,
#  'presumably': 498,
#  'problem': 499,
#  'problems': 500,
#  'process': 501,
#  'processes': 502,
#  'produced': 503,
#  'profession': 504,
#  'project': 505,
#  'pronounce': 506,
#  'put': 507,
#  'quarter': 508,
#  'quarters': 509,
#  'questionable': 510,
#  'quite': 511,
#  'rang': 512,
#  'rather': 513,
#  'read': 514,
#  'readers': 515,
#  'reasoner': 516,
#  'reasoning': 517,
#  'reasons': 518,
#  'received': 519,
#  'recent': 520,
#  'redheaded': 521,
#  'reigning': 522,
#  'release': 523,
#  'remained': 524,
#  'remarkable': 525,
#  'remarked': 526,
#  'remove': 527,
#  'restrictions': 528,
#  'results': 529,
#  'returned': 530,
#  'returning': 531,
#  'reuse': 532,
#  'ridiculously': 533,
#  'right': 534,
#  'rise': 535,
#  'risen': 536,
#  'room': 537,
#  'rooms': 538,
#  'round': 539,
#  'royal': 540,
#  'rubbed': 541,
#  'russian': 542,
#  'safely': 543,
#  'said': 544,
#  'save': 545,
#  'saw': 546,
#  'scandal': 547,
#  'scarlet': 548,
#  'scene': 549,
#  'scent': 550,
#  'scored': 551,
#  'scraped': 552,
#  'secreted': 553,
#  'see': 554,
#  'seen': 555,
#  'seized': 556,
#  'seldom': 557,
#  'sensitive': 558,
#  'sent': 559,
#  'sentencethis': 560,
#  'servant': 561,
#  'services': 562,
#  'set': 563,
#  'seven': 564,
#  'seventeen': 565,
#  'sex': 566,
#  'shared': 567,
#  'she': 568,
#  'sheet': 569,
#  'shelves': 570,
#  'sherlock': 571,
#  'shoe': 572,
#  'should': 573,
#  'show': 574,
#  'shown': 575,
#  'side': 576,
#  'signature': 577,
#  'signs': 578,
#  'silhouette': 579,
#  'silver': 580,
#  'simple': 581,
#  'simplicity': 582,
#  'since': 583,
#  'singular': 584,
#  'six': 585,
#  'slavey': 586,
#  'small': 587,
#  'smelling': 588,
#  'sneer': 589,
#  'so': 590,
#  'society': 591,
#  'softer': 592,
#  'sole': 593,
#  'some': 594,
#  'someone': 595,
#  'soul': 596,
#  'spare': 597,
#  'sparkled': 598,
#  'specimen': 599,
#  'speckled': 600,
#  'spirit': 601,
#  'spoke': 602,
#  'spoken': 603,
#  'stands': 604,
#  'start': 605,
#  'steps': 606,
#  'stethoscope': 607,
#  'stiff': 608,
#  'still': 609,
#  'stood': 610,
#  'story': 611,
#  'street': 612,
#  'strikes': 613,
#  'strong': 614,
#  'study': 615,
#  'successfully': 616,
#  'successive': 617,
#  'such': 618,
#  'sufficient': 619,
#  'suit': 620,
#  'suits': 621,
#  'summons': 622,
#  'sunk': 623,
#  'swiftly': 624,
#  't': 625,
#  'table': 626,
#  'take': 627,
#  'tall': 628,
#  'tell': 629,
#  'temperament': 630,
#  'terms': 631,
#  'texture': 632,
#  'than': 633,
#  'that': 634,
#  'the': 635,
#  'their': 636,
#  'then': 637,
#  'theories': 638,
#  'theorise': 639,
#  'there': 640,
#  'these': 641,
#  'they': 642,
#  'thick': 643,
#  'thing': 644,
#  'things': 645,
#  'think': 646,
#  'this': 647,
#  'those': 648,
#  'though': 649,
#  'thought': 650,
#  'threw': 651,
#  'through': 652,
#  'throw': 653,
#  'throwing': 654,
#  'thumb': 655,
#  'thursday': 656,
#  'time': 657,
#  'times': 658,
#  'title': 659,
#  'to': 660,
#  'together': 661,
#  'told': 662,
#  'tonight': 663,
#  'too': 664,
#  'took': 665,
#  'tophat': 666,
#  'tragedy': 667,
#  'trained': 668,
#  'trepoff': 669,
#  'trifle': 670,
#  'trifling': 671,
#  'trincomalee': 672,
#  'triumphant': 673,
#  'true': 674,
#  'trusted': 675,
#  'twentieth': 676,
#  'twice': 677,
#  'twist': 678,
#  'twisted': 679,
#  'two': 680,
#  'undated': 681,
#  'under': 682,
#  'until': 683,
#  'up': 684,
#  'updated': 685,
#  'upon': 686,
#  'us': 687,
#  'use': 688,
#  'utf': 689,
#  'v': 690,
#  'vague': 691,
#  'valley': 692,
#  'veil': 693,
#  'very': 694,
#  'vi': 695,
#  'vii': 696,
#  'viii': 697,
#  'vile': 698,
#  'visitor': 699,
#  'volume': 700,
#  'volunteer': 701,
#  'walk': 702,
#  'walks': 703,
#  'wallenstein': 704,
#  'was': 705,
#  'watson': 706,
#  'waved': 707,
#  'way': 708,
#  'we': 709,
#  'wear': 710,
#  'weather': 711,
#  'wedlock': 712,
#  'week': 713,
#  'well': 714,
#  'wellremembered': 715,
#  'were': 716,
#  'wet': 717,
#  'what': 718,
#  'whatsoever': 719,
#  'when': 720,
#  'where': 721,
#  'which': 722,
#  'while': 723,
#  'who': 724,
#  'whole': 725,
#  'wife': 726,
#  'will': 727,
#  'with': 728,
#  'without': 729,
#  'woman': 730,
#  'wooing': 731,
#  'word': 732,
#  'work': 733,
#  'world': 734,
#  'would': 735,
#  'woven': 736,
#  'writing': 737,
#  'written': 738,
#  'wrote': 739,
#  'wwwgutenbergnet': 740,
#  'x': 741,
#  'xi': 742,
#  'xii': 743,
#  'yet': 744,
#  'you': 745,
#  'your': 746,
#  'yours': 747,
#  'yourself': 748}

# %%
n_words = 10
input_words = []
next_words = []

for i in range(len(tokens)-n_words):
    input_words.append(tokens[i:i+n_words])
    next_words.append(tokens[i+n_words])

# %%
X = np.zeros((len(input_words),n_words,len(unique_tokens)),dtype = bool)
y = np.zeros((len(next_words),len(unique_tokens)),dtype = bool)

# %%
for i,words in enumerate(input_words):
    for j,word in enumerate(words):
        X[i,j,unique_token_index[word]] = 1
    y[i,unique_token_index[next_words[i]]] = 1

# %%
model = Sequential()
model.add(LSTM(128,input_shape = (n_words,len(unique_tokens)),return_sequences = True))
model.add(LSTM(128))
model.add(Dense(len(unique_tokens)))
model.add(Activation("softmax"))
# Out:
# C:\Users\Anurag Sunil\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(loss = "categorical_crossentropy",optimizer = RMSprop(learning_rate = 0.01),metrics = ["accuracy"])
history = model.fit(X,y,batch_size = 128,epochs = 30,shuffle = True)
# Out:
# Epoch 1/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.0367 - loss: 6.3781
# Epoch 2/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0526 - loss: 5.8078
# Epoch 3/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.0558 - loss: 5.7900
# Epoch 4/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.0530 - loss: 5.7235
# Epoch 5/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.0568 - loss: 5.7214
# Epoch 6/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.0549 - loss: 5.6100
# Epoch 7/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.0616 - loss: 5.5428
# Epoch 8/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.0640 - loss: 5.3906
# Epoch 9/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.0862 - loss: 5.1430
# Epoch 10/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.0810 - loss: 4.9893
# Epoch 11/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.0910 - loss: 4.7552
# Epoch 12/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1328 - loss: 4.4461
# Epoch 13/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - accuracy: 0.1428 - loss: 4.1942
# Epoch 14/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.1751 - loss: 3.9310
# Epoch 15/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.2003 - loss: 3.6217
# Epoch 16/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.2248 - loss: 3.3585
# Epoch 17/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.2751 - loss: 3.0422
# Epoch 18/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.3564 - loss: 2.7550
# Epoch 19/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.4401 - loss: 2.4367
# Epoch 20/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.5079 - loss: 2.1088
# Epoch 21/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.6154 - loss: 1.8033
# Epoch 22/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.6896 - loss: 1.5571
# Epoch 23/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7494 - loss: 1.3567
# Epoch 24/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8585 - loss: 0.9770
# Epoch 25/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8628 - loss: 0.9103
# Epoch 26/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9020 - loss: 0.7259
# Epoch 27/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.9276 - loss: 0.5629
# Epoch 28/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.9702 - loss: 0.3569
# Epoch 29/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.9758 - loss: 0.2849
# Epoch 30/30
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9625 - loss: 0.2974

# %%
model.save("mymodel.keras")

# %%
model = load_model("mymodel.keras")

# %%
def predict_next_word(input_text,n_best):
    input_text = input_text.lower()
    X = np.zeros((1,n_words,len(unique_tokens)))
    for i,word in enumerate(input_text.split()):
        X[0,i,unique_token_index[word]] = 1
    predictions = model.predict(X)[0]
    return np.argpartition(predictions,n_best)[-n_best:]

# %%
possible = predict_next_word("He will have to do that thing", 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step

# %%
print([unique_tokens[idx] for idx in possible])
# Out:
# ['yet', 'you', 'your', 'abhorrent', 'a']

# %%
def generate_text(input_text,text_length,creativity = 3):
    word_sequence = input_text.split()
    current = 0
    for _ in range(text_length):
        sub_sequence = " ".join(tokenizer.tokenize(" ".join(word_sequence).lower())[current:current+n_words])
        try:
            choice = unique_tokens[random.choice(predict_next_word(sub_sequence,creativity))]
        except:
            choice = random.choice(unique_tokens)
        word_sequence.append(choice)
        current+=1
    return " ".join(word_sequence)

# %%
generate_text("clothes I can’t imagine how you deduce it",100,5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 'clothes I can’t imagine how you deduce it yet yet you yet a adler yourself akin yours yet you a a yet your a a a you a your yours yet a yet yours your yet yet yet you yours again yet adler yet adventures a yet yet a adler london you absorb you yours yet your you yet active as yet yet yours a yet a ago absorb yet your yet your yet yours yet abhorrent a adler yourself across absorb yet absorb yours yours a a akin london you yours yet yours a yet you you yet yours an yours yours your a you your yours'
